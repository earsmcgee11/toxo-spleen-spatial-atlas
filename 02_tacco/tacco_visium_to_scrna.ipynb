# %% [markdown]
# # TACCO skeleton (Figure 2D)
#
# In the manuscript, Visium niche signatures were transferred onto the scRNA-seq atlas with **TACCO** (Mages et al., 2023) so each cell gets a compositional score for each spatial niche (Fig. 2D).
#
# This notebook is a **methods skeleton only** (parameters + expected I/O). It is not a fully executed analysis notebook from this repository’s primary spatial workflows. For the definitive description, see the manuscript Methods (“TACCO”).
#
# **Manuscript parameters** (`tc.tl.annotate`):
# - `normalize_to='reference'`
# - `bisections=20`, `bisection_divisor=19`
# - `assume_valid_counts=True`, `lamb=0`
# - `min_log2foldchange=0`, `min_genes_per_cell=1`
#
# **Expected inputs**
# - Visium AnnData with niche labels (`paper_clusters` / tissue regions)
# - scRNA-seq atlas AnnData
#
# **Expected output**
# - Per-cell niche composition scores → UMAP panels as in Fig. 2D

# %% [markdown]
# ## Placeholder: paths and annotate call
#
# Fill in local paths if you re-run. This cell is illustrative.

# %%
# Illustrative only — not executed as part of this repo's primary analyses.
#
# import tacco as tc
# import scanpy as sc
#
# sc_adata = sc.read_h5ad("data/sc_atlas.h5ad")
# st_adata = sc.read_h5ad("data/visium_annotated.h5ad")
# # st_adata.obs["tissue_regions"] = ...  # niche labels from Fig. 2
#
# tc.tl.annotate(
#     sc_adata,
#     st_adata,
#     "tissue_regions",
#     result_key="tissue_regions",
#     normalize_to="reference",
#     bisections=20,
#     bisection_divisor=19,
#     assume_valid_counts=True,
#     lamb=0,
#     min_log2foldchange=0,
#     min_genes_per_cell=1,
# )
# # scores in sc_adata.obsm["tissue_regions"] → Fig. 2D UMAPs
print("TACCO skeleton: see markdown above and manuscript Methods.")
